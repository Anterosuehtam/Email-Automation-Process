# %%
import pyautogui
import time
import pyperclip

# %%
import pyautogui
import time
import pyperclip
    

pyautogui.hotkey("ctrl", "t")

pyautogui.click(x=661, y=50)
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl","v")
time.sleep(1)
pyautogui.hotkey("enter")
time.sleep(7)

#Dentro da caixa de email: colocar o email, preecher o assunto, escrever o corpo do email e enviar
pyautogui.click(x=26, y=180)
time.sleep(5)
pyautogui.hotkey("alt","tab")
pyautogui.click(x=51, y=198)
pyautogui.write("E3")
time.sleep(1)
pyautogui.hotkey("enter")


#Aqui você deverá colocar a cordenada da tela onde a celula está, copiar e já era. 
for a in range (5):
    time.sleep(1)
    pyautogui.hotkey("ctrl","c")
    time.sleep(1)
    pyautogui.press("down")
    time.sleep(1)
    pyautogui.hotkey("alt","tab")
    time.sleep(1)
    pyautogui.hotkey("ctrl","v")
    time.sleep(1)
    pyautogui.press("enter")
    time.sleep(1)
    pyautogui.hotkey("alt","tab")
time.sleep(1)
pyautogui.hotkey("alt","tab")
pyautogui.press("tab")

time.sleep(1)
pyautogui.write("Compra de Videogames")
time.sleep(1)
pyautogui.press("tab")
time.sleep(1)
pyperclip.copy("""Olá, somos a Sagart Company e estamos confirmando que seu pedido efetuado no site Casas Bahia referente à 100 videogames foi realizado com sucesso.


Modelo: Playstation 5
Data do pedido: 13/10/2022
Valor da compra: 200.000
Método de Pagamento: Crédito especial

Att,
Equipe Sagart


Por favor, pedimos que você não responda esse e-mail, pois se trata de uma mensagem automática e não é possível dar continuidade com seu atendimento por aqui.


Para emergências ligue para 0800 0222 2000. Atendimentos são realizados 24 horas, todos os dias pelo chat ou telefone.

Sagart S.M - Instituição de mediações 18.236.120/0001-58
Rua Fazenda da Juta, 39 -  05409-000- São Paulo - SP""")
pyautogui.hotkey("ctrl","v")
time.sleep(1)
pyautogui.hotkey("enter")
time.sleep(1)


#Inserindo uma foto
pyautogui.click(x=1062, y=732)
time.sleep(5)
pyautogui.click(x=642, y=480)
time.sleep(5)
pyautogui.click(x=667, y=252)
time.sleep(5)
pyautogui.click(x=585, y=525)
time.sleep(5)


#Enviar o email
pyautogui.hotkey("tab")
time.sleep(1)
pyautogui.hotkey("enter")
time.sleep(3)

#Fazer o processo de novo
pyautogui.click(x=26, y=180)
time.sleep(5)
pyautogui.hotkey("alt","tab")

for a in range (5):
    time.sleep(1)
    pyautogui.hotkey("ctrl","c")
    time.sleep(1)
    pyautogui.press("down")
    time.sleep(1)
    pyautogui.hotkey("alt","tab")
    time.sleep(1)
    pyautogui.hotkey("ctrl","v")
    time.sleep(1)
    pyautogui.press("enter")
    time.sleep(1)
    pyautogui.hotkey("alt","tab")
time.sleep(1)
pyautogui.hotkey("alt","tab")    
pyautogui.press("tab")
time.sleep(1)
pyautogui.write("Compra de Chipsets")
time.sleep(1)
pyautogui.press("tab")
time.sleep(1)
pyperclip.copy("""Olá, somos a Sagart Company e estamos confirmando que seu pedido efetuado no site Kabum! referente à 11.000 Chipsets foi realizado com sucesso.


Modelo: AMD Ryzen Threadripper PRO
Série: 100-100000444WOF
Data do pedido: 13/10/2022
Valor da compra: 130.000.00
Método de Pagamento: Cheque Especial

Att,
Equipe Sagart


Por favor, pedimos que você não responda esse e-mail, pois se trata de uma mensagem automática e não é possível dar continuidade com seu atendimento por aqui.


Para emergências ligue para 0800 0222 2000. Atendimentos são realizados 24 horas, todos os dias pelo chat ou telefone.

Sagart S.M - Instituição de mediações 18.236.120/0001-58
Rua Fazenda da Juta, 39 -  05409-000- São Paulo - SP""")
pyautogui.hotkey("ctrl","v")
time.sleep(1)
pyautogui.hotkey("enter")
time.sleep(3)

#Inserindo uma foto
pyautogui.click(x=1062, y=732)
time.sleep(5)
pyautogui.click(x=642, y=480)
time.sleep(5)
pyautogui.click(x=667, y=252)
time.sleep(5)
pyautogui.click(x=585, y=525)
time.sleep(5)


#Enviar o email
pyautogui.hotkey("tab")
time.sleep(1)
pyautogui.hotkey("enter")
time.sleep(3)

#Fazer o processo de novo
pyautogui.click(x=26, y=180)
time.sleep(5)
pyautogui.hotkey("alt","tab")

for a in range (5):
    time.sleep(1)
    pyautogui.hotkey("ctrl","c")
    time.sleep(1)
    pyautogui.press("down")
    time.sleep(1)
    pyautogui.hotkey("alt","tab")
    time.sleep(1)
    pyautogui.hotkey("ctrl","v")
    time.sleep(1)
    pyautogui.press("enter")
    time.sleep(1)
    pyautogui.hotkey("alt","tab")
time.sleep(1)
pyautogui.hotkey("alt","tab")    
pyautogui.press("tab")
time.sleep(1)
pyautogui.write("Compra de Monitores")
time.sleep(1)
pyautogui.press("tab")
time.sleep(1)
pyperclip.copy("""Olá, somos a Sagart Company e estamos confirmando que seu pedido efetuado no site Magazine Luiza referente à 15 monitores foi realizado com sucesso.



Modelo: MSI OPTIX G241 23
Série: OPTIX-G241
Data do pedido: 13/10/2022
Valor da compra: 30.000
Método de Pagamento: Cheque Especial

Att,
Equipe Sagart


Por favor, pedimos que você não responda esse e-mail, pois se trata de uma mensagem automática e não é possível dar continuidade com seu atendimento por aqui.


Para emergências ligue para 0800 0222 2000. Atendimentos são realizados 24 horas, todos os dias pelo chat ou telefone.

Sagart S.M - Instituição de mediações 18.236.120/0001-58
Rua Fazenda da Juta, 39 -  05409-000- São Paulo - SP""")
pyautogui.hotkey("ctrl","v")
time.sleep(1)
pyautogui.hotkey("enter")
time.sleep(3)

#Inserindo uma foto
pyautogui.click(x=1062, y=732)
time.sleep(5)
pyautogui.click(x=642, y=480)
time.sleep(5)
pyautogui.click(x=667, y=252)
time.sleep(5)
pyautogui.click(x=585, y=525)
time.sleep(5)


#Enviar o email
pyautogui.hotkey("tab")
time.sleep(1)
pyautogui.hotkey("enter")
time.sleep(3)

pyautogui.hotkey("ctrl","w")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [37], in <cell line: 214>()
#     212 time.sleep(5)
#     213 pyautogui.click(x=642, y=480)
# --> 214 time.sleep(5)
#     215 pyautogui.click(x=667, y=252)
#     216 time.sleep(5)
#
# KeyboardInterrupt:

# %%
import pyautogui
import time

time.sleep(6)
pyautogui.position()
